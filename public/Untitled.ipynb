# %%
import pandas as pd

# %%
df = pd.read_csv('product_list_csv.csv')

# %%
df.head(100)
# Out:
#     Material                            Description  \
# 0    8101007              BEAR BRAND MILK STER TIN
# 1    1151241              BEAR BRAND MILK STER TIN
# 2    8101008              BEAR BRAND MILK STER TIN
# 3    1151207         BEAR BRAND MILK STER  30x150ml
# 4    1151215       BEAR BRAND MILK STER 12(4x150ml)
# ..       ...                                    ...
# 59   1151293  Nutriwell UHT Omega Flax 12x(4x180ml)
# 60   1201514           HAYOCO COOL COLA 70GX12X4 TH
# 61   1201578     HAYOCO BERRY BEAR 70G X 12 X 4  TH
# 62   1201617     HAYOCO BERRY BEAR 15G X 12 X 12 TH
# 63   1201618     HAYOCO COOL COLA 15G X 12 X 12  TH
#
#                                     Thai Desc.      Pack Size Product Group  \
# 0              นมสเตอริไลส์ตราหมี 8(12x140มล.)  8X(12X140 ml)           STM
# 1        นมสดสเตอริไลส์ตราหมี 8(12x140มล.) P12  8X(12X140 ml)           STM
# 2              นมสเตอริไลส์ตราหมี 16(6X140มล.)  16X(6X140 ml)           STM
# ...

# %%
# กำหนดบาร์โค้ดที่ต้องการค้นหา
search_code = "8858705604595"

# ค้นหาจากทั้ง 3 คอลัมน์บาร์โค้ด
result = df[
    (df['Bar Code EA'] == search_code) |
    (df['Bar Code DSP'] == search_code) |
    (df['Bar Code CS'] == search_code)
]

# แสดงผลลัพธ์
print(result)
# Out:
#     Material                Description  \
# 52   1151045  MAGNOLIA GINKGO CHOC UHT
#
#                                    Thai Desc.      Pack Size Product Group  \
# 52  นมแมกโนเลีย กิงโกะ ช็อกโกแลต 12x(4X180มล)  12x(4X180 ml)  Magnolia UHT
#
#     Shelflife (Months)    Bar Code EA   Bar Code DSP     Bar Code CS
# 52                   9  8858705604588  8858705604595  18858705604608

# %%
# กำหนดบาร์โค้ดที่ต้องการค้นหา
search_code = "8858705605592"

# ค้นหาจากทั้ง 3 คอลัมน์บาร์โค้ด
result = df[
    (df['Bar Code EA'] == search_code) |
    (df['Bar Code DSP'] == search_code) |
    (df['Bar Code CS'] == search_code)
]

# แสดงผลลัพธ์
print(result)
# Out:
#     Material                     Description                    Thai Desc.  \
# 28   1112148  CARNATION EVP MILK SHAPED CAN   นมข้นจืดคาร์เนชัน 24X140 มล.
#
#     Pack Size Product Group  Shelflife (Months)    Bar Code EA Bar Code DSP  \
# 28  24X140 ml          EVAP                  12  8858705605592            -
#
#        Bar Code CS
# 28  18858705605605
